# %%
pip install snowflake-snowpark-python
# Out:
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 11.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 14.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    ----------------------- ---------------- 8.4/14.0 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.0 MB 41.6 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.0 MB 41.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.0/14.0 MB 20.5 MB/s eta 0:00:00
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.13.1-py3-none-any.whl (85 kB)
# ...
#   Attempting uninstall: cloudpickle
# ...

# %% [markdown]
# # snowpark transformation

# %% [markdown]
# ## session configuration

# %%
from snowflake.snowpark.session import Session
import snowflake.snowpark.functions as F
from datetime import datetime, date

# %%
def create_session():
    connection_parameters = {
        "account": "FUOTJRL-JKB28775",
        "user": "VALDESATOS",
        "password": "16081997Botel!",
        "role": "ACCOUNTADMIN",
        "warehouse": "COMPUTE_WH",
    }
    session = Session.builder.configs(connection_parameters).create()
    return session

# %%
demo_session = create_session()

# %%
df = demo_session.sql("select * from snowflake_sample_data.tpch_sf10.lineitem limit 1000")

# %%
df.show(10)
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"L_ORDERKEY"  |"L_PARTKEY"  |"L_SUPPKEY"  |"L_LINENUMBER"  |"L_QUANTITY"  |"L_EXTENDEDPRICE"  |"L_DISCOUNT"  |"L_TAX"  |"L_RETURNFLAG"  |"L_LINESTATUS"  |"L_SHIPDATE"  |"L_COMMITDATE"  |"L_RECEIPTDATE"  |"L_SHIPINSTRUCT"   |"L_SHIPMODE"  |"L_COMMENT"                               |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df.collect()
# Out:
# [Row(L_ORDERKEY=6600001, L_PARTKEY=1267154, L_SUPPKEY=67155, L_LINENUMBER=1, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('25785.07'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 5, 29), L_COMMITDATE=datetime.date(1996, 5, 12), L_RECEIPTDATE=datetime.date(1996, 6, 15), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='ns among the sly'),
#  Row(L_ORDERKEY=6600001, L_PARTKEY=1042915, L_SUPPKEY=92936, L_LINENUMBER=2, L_QUANTITY=Decimal('21.00'), L_EXTENDEDPRICE=Decimal('39015.06'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 3, 9), L_COMMITDATE=datetime.date(1996, 4, 16), L_RECEIPTDATE=datetime.date(1996, 4, 8), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT='le blithely al'),
# ...

# %%
# se positionner sur la base de donnnées et le schéma
demo_session.use_database("snowflake_sample_data")
demo_session.use_schema("tpch_sf10")

# %%
# se positionner sur une table spécifique
df = demo_session.table("lineitem")

# %%
df_selected = df.select(
                    "l_shipdate",
                    "l_extendedprice",
                    "l_shipmode",
                    "l_quantity",
                    "l_discount"
                    ).filter(F.col("l_shipdate").between(date(1997,1,1), date(1997,12,31)))

# %%
df_selected.show(10)
# Out:
# ---------------------------------------------------------------------------------
# |"L_SHIPDATE"  |"L_EXTENDEDPRICE"  |"L_SHIPMODE"  |"L_QUANTITY"  |"L_DISCOUNT"  |
# ---------------------------------------------------------------------------------
# |1997-11-04    |67299.75           |TRUCK         |35.00         |0.05          |
# |1997-09-20    |62000.90           |SHIP          |37.00         |0.03          |
# |1997-12-22    |12149.34           |RAIL          |7.00          |0.07          |
# |1997-11-09    |1145.07            |AIR           |1.00          |0.09          |
# |1997-09-15    |23692.65           |AIR           |15.00         |0.09          |
# |1997-09-12    |51500.26           |MAIL          |38.00         |0.02          |
# |1997-03-01    |60622.80           |SHIP          |49.00         |0.08          |
# |1997-01-28    |48496.96           |RAIL          |32.00         |0.00          |
# ...
